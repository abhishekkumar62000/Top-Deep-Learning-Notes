# %% [markdown]
# ![image.png](attachment:33a673ae-2f33-45a2-87cb-b0bb30df17dd.png)

# %% [markdown]
# ![image.png](attachment:1730d8ba-b729-4ad1-a7c9-eff7e5dbb994.png)

# %% [markdown]
# ![image.png](attachment:222b2aaa-7adc-4e85-a3b9-affbbdac9d44.png)

# %% [markdown]
# ![image.png](attachment:ce0b3456-7117-4823-9417-421eef70aed0.png)

# %% [markdown]
# ![image.png](attachment:c6f46e30-8ed9-4449-8811-b4f16dd27422.png)

# %% [markdown]
# ![image.png](attachment:0cf0dc4d-30ab-42d3-a07f-096e4315f3f4.png)

# %% [markdown]
# ![image.png](attachment:60cee466-4437-4865-91cd-03cf5bd1a44a.png)

# %% [markdown]
# ![image.png](attachment:dcb0ff87-9594-4872-bdac-1666c8045d01.png)

# %% [markdown]
# ![image.png](attachment:cffc3cbc-916d-4961-b1e6-36242637ee4c.png)

# %% [markdown]
# ![image.png](attachment:266db14d-bb03-4299-97ac-27d6c1bee21a.png)
